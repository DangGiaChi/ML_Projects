# %% [markdown]
# **House price prediction**

# %% [markdown]
# This is a project to practiced what has been learned in Car_price_prediction.ipynb

# %% [markdown]
# **Note for myself:** For some reason the kernel with `Normalization()` crashes when using Python 3.10.xx, so for this notebook I am using Python 3.8.18

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from urllib.request import urlretrieve
from tensorflow.keras.layers import Normalization
from tensorflow.keras.layers import InputLayer, Dense
from tensorflow.keras.activations import relu
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers.legacy import Adam

# %%
dataset_url = "https://raw.githubusercontent.com/DangGiaChi/Tensorflow-Course/main/Car-Price-Prediction/train_house.csv"
urlretrieve(dataset_url, "train_2.csv")
dataset = pd.read_csv("train_2.csv")
print(dataset)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %% [markdown]
# Now let's leave out unwanted columns like date or location, as the location of all these houses are in the USA

# %%
dataset_columns = list(dataset)
unwanted_columns = ["date", "street", "city", "statezip", 'country']

dataset_columns = [data for data in dataset if data not in unwanted_columns]
dataset = dataset[dataset_columns]
print(dataset)
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0              0     0          3        1340              0      1955
# 1              0     4          5        3370            280      1921
# 2              0     0          4        1930              0      1966
# 3              0     0          4        1000           1000      1963
# 4              0     0          4        1140            800      1976
# ...          ...   ...        ...         ...            ...       ...
# 4595           0     0          4        1510              0      1954
# 4596           0     0          3        1460              0      1983
# 4597           0     0          3        3010              0      2009
# 4598           0     0          3        1070           1020      1974
# 4599           0     0          4        1490              0      1990
#
#       yr_renovated
# 0             2005
# 1                0
# 2                0
# 3                0
# 4             1992
# ...            ...
# 4595          1979
# 4596          2009
# 4597             0
# 4598             0
# 4599             0
#
# [4600 rows x 13 columns]

# %%
sns.pairplot(data=dataset, x_vars=list(dataset), y_vars=["price"], diag_kind="kde")

# %% [markdown]
# Looking at these graphs, we can see that there is quite a few outliers. That why we'll be using Huber's loss function

# %%
dataset = tf.constant(dataset)
dataset = tf.cast(dataset, dtype=tf.float32)
dataset = tf.random.shuffle(dataset)
print(dataset)
# Out:
# tf.Tensor(
# [[3.200e+05 4.000e+00 1.500e+00 ... 0.000e+00 1.974e+03 0.000e+00]
#  [1.920e+05 2.000e+00 1.000e+00 ... 0.000e+00 1.953e+03 0.000e+00]
#  [2.000e+05 3.000e+00 1.000e+00 ... 0.000e+00 1.938e+03 0.000e+00]
#  ...
#  [5.500e+05 4.000e+00 1.500e+00 ... 1.250e+03 1.958e+03 0.000e+00]
#  [7.820e+05 4.000e+00 3.500e+00 ... 1.830e+03 2.004e+03 2.003e+03]
#  [9.270e+05 4.000e+00 2.750e+00 ... 0.000e+00 1.953e+03 0.000e+00]], shape=(4600, 13), dtype=float32)

# %%
X = dataset[:, 1:]
Y = dataset[:, 0]
Y = tf.expand_dims(Y, axis=1)
print(X.shape)
print(Y.shape)
# Out:
# (4600, 12)
# (4600, 1)

# %% [markdown]
# We'll choose 80% for training set, 10% for validation set and 10% for test set

# %% [markdown]
# But since we will use `validation_split` in `model.fit()`, we only need to initialize training set (training + validation: 90%) and test set

# %% [markdown]
# **Correction:** I initially wanted to use `validation_split` but it is only possible if the type of `data` is numpy or tensor. What a shame.

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1
TEST_RATIO = 1 - TRAIN_RATIO - VAL_RATIO

# %%
x_train = X[:int(len(X) * TRAIN_RATIO)]
y_train = Y[:int((len(Y) * TRAIN_RATIO))]
print(x_train.shape)
print(y_train.shape)
# Out:
# (3680, 12)
# (3680, 1)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=400, reshuffle_each_iteration=True).batch(150).prefetch(tf.data.AUTOTUNE)

# %%
x_val = X[int(len(X) * TRAIN_RATIO): int(len(X) * (TRAIN_RATIO + VAL_RATIO))]
y_val = Y[int((len(Y) * TRAIN_RATIO)): int(len(Y) * (TRAIN_RATIO + VAL_RATIO))]
print(x_val.shape)
print(y_val.shape)
# Out:
# (460, 12)
# (460, 1)

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.shuffle(buffer_size=400, reshuffle_each_iteration=True).batch(150).prefetch(tf.data.AUTOTUNE)

# %%
x_test = X[int(len(X) * (TRAIN_RATIO + VAL_RATIO)):]
y_test = Y[int(len(Y) * (TRAIN_RATIO + VAL_RATIO)):]
print(x_test.shape)
print(y_test.shape)
# Out:
# (460, 12)
# (460, 1)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dataset = test_dataset.shuffle(buffer_size=400, reshuffle_each_iteration=True).batch(150).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# Now we initialize the normalize layer

# %%
normalizer = Normalization()
normalizer.adapt(x_train)
normalizer(x_train)
# Out:
# 2024-01-26 23:26:12.459299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-26 23:26:12.475523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# <tf.Tensor: shape=(3680, 12), dtype=float32, numpy=
# array([[ 0.6569154 , -0.8332916 , -0.25565267, ..., -0.6761381 ,
#          0.10278211, -0.829419  ],
#        [-1.5417634 , -1.4648466 , -1.4662051 , ..., -0.6761381 ,
#         -0.6086165 , -0.829419  ],
#        [-0.442424  , -1.4648466 , -1.0084331 , ..., -0.6761381 ,
#         -1.1167582 , -0.829419  ],
#        ...,
#        [ 0.6569154 , -0.5175141 ,  0.73110014, ...,  1.7800977 ,
#          0.2382866 , -0.829419  ],
#        [ 1.7562549 , -0.20173661, -0.3065162 , ..., -0.03538093,
#         -0.9812538 ,  1.1686763 ],
#        [ 0.6569154 ,  0.42981833,  0.8735181 , ..., -0.6761381 ,
#         -1.1506344 ,  1.2054135 ]], dtype=float32)>

# %% [markdown]
# **Model Initialization and Training**

# %% [markdown]
# Now, it's finally time to train our model

# %%
model_house = tf.keras.models.Sequential([
    InputLayer(input_shape = (12,)), 
    normalizer,
    Dense(128, activation = "relu"),
    Dense(1)
])
model_house.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_6 (Normaliza  (None, 12)                25
#  tion)
#
#  dense_12 (Dense)            (None, 128)               1664
#
#  dense_13 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 1818 (7.11 KB)
# Trainable params: 1793 (7.00 KB)
# Non-trainable params: 25 (104.00 Byte)
# _________________________________________________________________

# %% [markdown]
# As mentioned above, this dataset contains a lot of outliers, that's why we'll be using Huber's loss function

# %%
model_house.compile(optimizer=Adam(learning_rate = 1),
              metrics=RootMeanSquaredError(),
              loss = Huber(delta = 1.35))

# %%
process = model_house.fit(train_dataset, validation_data=val_dataset, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 10/25 [===========>..................] - ETA: 0s - loss: 754909.0000 - root_mean_squared_error: 958262.0625
# 2024-01-26 23:26:12.825364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 1s 12ms/step - loss: 733151.3125 - root_mean_squared_error: 816197.0000 - val_loss: 651122.0625 - val_root_mean_squared_error: 575992.8125
# Epoch 2/100
# 11/25 [============>.................] - ETA: 0s - loss: 657280.2500 - root_mean_squared_error: 896295.9375
# 2024-01-26 23:26:13.158655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 0s 6ms/step - loss: 602326.5625 - root_mean_squared_error: 765332.3125 - val_loss: 433742.5625 - val_root_mean_squared_error: 453121.7500
# Epoch 3/100
# 25/25 [==============================] - 0s 6ms/step - loss: 365727.9375 - root_mean_squared_error: 646025.2500 - val_loss: 241937.0312 - val_root_mean_squared_error: 266899.6562
# Epoch 4/100
# 25/25 [==============================] - 0s 6ms/step - loss: 246652.2188 - root_mean_squared_error: 563010.3125 - val_loss: 199204.4062 - val_root_mean_squared_error: 217206.2031
# Epoch 5/100
# 25/25 [==============================] - 0s 6ms/step - loss: 234294.2812 - root_mean_squared_error: 548844.6875 - val_loss: 195636.5156 - val_root_mean_squared_error: 214382.6875
# Epoch 6/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231839.3906 - root_mean_squared_error: 546910.1875 - val_loss: 194792.4062 - val_root_mean_squared_error: 214311.6562
# Epoch 7/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231426.0312 - root_mean_squared_error: 546761.8125 - val_loss: 195676.6250 - val_root_mean_squared_error: 214540.0625
# Epoch 8/100
# 25/25 [==============================] - 0s 5ms/step - loss: 230697.4219 - root_mean_squared_error: 546774.6875 - val_loss: 195949.8750 - val_root_mean_squared_error: 215184.2812
# Epoch 9/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231890.2656 - root_mean_squared_error: 547170.5000 - val_loss: 197400.2031 - val_root_mean_squared_error: 216841.1562
# Epoch 10/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232084.2500 - root_mean_squared_error: 546842.6250 - val_loss: 197506.0312 - val_root_mean_squared_error: 216828.2188
# Epoch 11/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233532.5156 - root_mean_squared_error: 547697.8750 - val_loss: 197574.3438 - val_root_mean_squared_error: 217536.2969
# Epoch 12/100
# 25/25 [==============================] - 0s 6ms/step - loss: 230995.5000 - root_mean_squared_error: 546367.6250 - val_loss: 196705.4375 - val_root_mean_squared_error: 215681.8281
# Epoch 13/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232621.3594 - root_mean_squared_error: 546723.9375 - val_loss: 194667.2344 - val_root_mean_squared_error: 212708.3594
# Epoch 14/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231003.7031 - root_mean_squared_error: 546277.5625 - val_loss: 195904.2031 - val_root_mean_squared_error: 214842.1250
# Epoch 15/100
# 25/25 [==============================] - 0s 6ms/step - loss: 231819.5000 - root_mean_squared_error: 546402.8125 - val_loss: 195961.1406 - val_root_mean_squared_error: 214223.2969
# Epoch 16/100
# 25/25 [==============================] - 0s 6ms/step - loss: 231251.8125 - root_mean_squared_error: 546283.9375 - val_loss: 195556.2031 - val_root_mean_squared_error: 214932.3594
# Epoch 17/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233449.1875 - root_mean_squared_error: 547012.9375 - val_loss: 197925.6250 - val_root_mean_squared_error: 217831.4531
# Epoch 18/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232014.3125 - root_mean_squared_error: 546787.0000 - val_loss: 199332.9688 - val_root_mean_squared_error: 219943.9375
# Epoch 19/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232980.0000 - root_mean_squared_error: 547491.9375 - val_loss: 199310.3594 - val_root_mean_squared_error: 217703.2031
# Epoch 20/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231394.9688 - root_mean_squared_error: 546158.3750 - val_loss: 195071.1719 - val_root_mean_squared_error: 214478.3594
# Epoch 21/100
# 25/25 [==============================] - 0s 5ms/step - loss: 230934.1094 - root_mean_squared_error: 546665.7500 - val_loss: 196985.1406 - val_root_mean_squared_error: 216214.1719
# Epoch 22/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231489.6875 - root_mean_squared_error: 546111.3125 - val_loss: 200923.5000 - val_root_mean_squared_error: 220380.0781
# Epoch 23/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232611.4062 - root_mean_squared_error: 547893.6875 - val_loss: 199705.5156 - val_root_mean_squared_error: 220129.5625
# Epoch 24/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232068.3750 - root_mean_squared_error: 547395.4375 - val_loss: 200026.4531 - val_root_mean_squared_error: 219456.6094
# Epoch 25/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232744.1562 - root_mean_squared_error: 547202.0000 - val_loss: 194628.7969 - val_root_mean_squared_error: 213241.4375
# Epoch 26/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232611.2031 - root_mean_squared_error: 547054.1875 - val_loss: 200989.1875 - val_root_mean_squared_error: 221151.5156
# Epoch 27/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231622.9531 - root_mean_squared_error: 546006.4375 - val_loss: 194665.6719 - val_root_mean_squared_error: 213357.3281
# Epoch 28/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233268.1875 - root_mean_squared_error: 546713.6250 - val_loss: 201893.7344 - val_root_mean_squared_error: 222258.0781
# Epoch 29/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235542.5625 - root_mean_squared_error: 547258.5625 - val_loss: 196696.3438 - val_root_mean_squared_error: 217624.8594
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234038.2188 - root_mean_squared_error: 547251.3125 - val_loss: 199276.5781 - val_root_mean_squared_error: 220110.2344
# Epoch 31/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233934.7031 - root_mean_squared_error: 548127.1250 - val_loss: 196106.2812 - val_root_mean_squared_error: 216891.1250
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232721.3594 - root_mean_squared_error: 546614.6875 - val_loss: 195125.5156 - val_root_mean_squared_error: 215255.9688
# Epoch 33/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232089.0156 - root_mean_squared_error: 545866.1250 - val_loss: 194504.1875 - val_root_mean_squared_error: 213830.6562
# Epoch 34/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234532.5156 - root_mean_squared_error: 549161.7500 - val_loss: 195131.5781 - val_root_mean_squared_error: 214854.0469
# Epoch 35/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232276.2812 - root_mean_squared_error: 547011.1250 - val_loss: 195277.0312 - val_root_mean_squared_error: 215435.0000
# Epoch 36/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233491.2031 - root_mean_squared_error: 547536.0000 - val_loss: 194518.6562 - val_root_mean_squared_error: 214024.8906
# Epoch 37/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232688.7656 - root_mean_squared_error: 547030.6875 - val_loss: 197125.6250 - val_root_mean_squared_error: 214208.7188
# Epoch 38/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232555.9844 - root_mean_squared_error: 546927.5625 - val_loss: 194644.2031 - val_root_mean_squared_error: 213674.2969
# Epoch 39/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235588.2812 - root_mean_squared_error: 549360.0000 - val_loss: 199894.7812 - val_root_mean_squared_error: 213323.3125
# Epoch 40/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233524.4375 - root_mean_squared_error: 548075.5000 - val_loss: 195660.4375 - val_root_mean_squared_error: 213752.5469
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234127.5469 - root_mean_squared_error: 547711.3750 - val_loss: 195661.3438 - val_root_mean_squared_error: 216113.6406
# Epoch 42/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232387.4062 - root_mean_squared_error: 546780.8125 - val_loss: 195942.5156 - val_root_mean_squared_error: 213682.4844
# Epoch 43/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231714.0625 - root_mean_squared_error: 546079.4375 - val_loss: 194228.5938 - val_root_mean_squared_error: 213626.6719
# Epoch 44/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232266.3750 - root_mean_squared_error: 545887.4375 - val_loss: 195348.3125 - val_root_mean_squared_error: 214744.4531
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231494.4531 - root_mean_squared_error: 546457.5000 - val_loss: 195274.3125 - val_root_mean_squared_error: 214273.1406
# Epoch 46/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232285.7344 - root_mean_squared_error: 546615.4375 - val_loss: 194183.8594 - val_root_mean_squared_error: 212606.7812
# Epoch 47/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231351.1094 - root_mean_squared_error: 546549.1250 - val_loss: 195773.3594 - val_root_mean_squared_error: 212458.4375
# Epoch 48/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232485.0469 - root_mean_squared_error: 547000.1250 - val_loss: 197643.7812 - val_root_mean_squared_error: 212626.5312
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232417.6250 - root_mean_squared_error: 546858.4375 - val_loss: 196133.4844 - val_root_mean_squared_error: 213643.8125
# Epoch 50/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231649.7812 - root_mean_squared_error: 547152.0625 - val_loss: 199425.1406 - val_root_mean_squared_error: 215612.1562
# Epoch 51/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233883.0156 - root_mean_squared_error: 547821.1250 - val_loss: 198711.3594 - val_root_mean_squared_error: 219766.0781
# Epoch 52/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232615.8125 - root_mean_squared_error: 546607.3125 - val_loss: 194846.2500 - val_root_mean_squared_error: 215041.5781
# Epoch 53/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231935.5156 - root_mean_squared_error: 546813.8750 - val_loss: 195064.3125 - val_root_mean_squared_error: 214468.5625
# Epoch 54/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234771.5312 - root_mean_squared_error: 548869.3750 - val_loss: 195619.1094 - val_root_mean_squared_error: 216625.0781
# Epoch 55/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232174.6406 - root_mean_squared_error: 547280.8125 - val_loss: 194768.0938 - val_root_mean_squared_error: 214403.0156
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232104.8281 - root_mean_squared_error: 546858.5625 - val_loss: 194964.8594 - val_root_mean_squared_error: 215020.6250
# Epoch 57/100
# 25/25 [==============================] - 0s 6ms/step - loss: 231661.2500 - root_mean_squared_error: 546858.6250 - val_loss: 195726.0156 - val_root_mean_squared_error: 212748.2969
# Epoch 58/100
# 25/25 [==============================] - 0s 6ms/step - loss: 232885.7188 - root_mean_squared_error: 547058.0000 - val_loss: 194619.7969 - val_root_mean_squared_error: 213676.9219
# Epoch 59/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235784.4844 - root_mean_squared_error: 548861.2500 - val_loss: 198116.8125 - val_root_mean_squared_error: 219073.2031
# Epoch 60/100
# 25/25 [==============================] - 0s 6ms/step - loss: 232992.1406 - root_mean_squared_error: 547752.8750 - val_loss: 198282.2656 - val_root_mean_squared_error: 213464.3750
# Epoch 61/100
# 25/25 [==============================] - 0s 6ms/step - loss: 232069.5312 - root_mean_squared_error: 546281.0625 - val_loss: 194929.2500 - val_root_mean_squared_error: 214120.1250
# Epoch 62/100
# 25/25 [==============================] - 0s 6ms/step - loss: 231456.5156 - root_mean_squared_error: 546119.8750 - val_loss: 197431.7344 - val_root_mean_squared_error: 213074.8438
# Epoch 63/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233256.4062 - root_mean_squared_error: 547279.3750 - val_loss: 201192.2500 - val_root_mean_squared_error: 214193.0625
# Epoch 64/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235453.1406 - root_mean_squared_error: 548741.2500 - val_loss: 195457.8594 - val_root_mean_squared_error: 213899.3906
# Epoch 65/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233466.4375 - root_mean_squared_error: 546548.6875 - val_loss: 194766.5469 - val_root_mean_squared_error: 215112.0938
# Epoch 66/100
# 25/25 [==============================] - 0s 6ms/step - loss: 232467.1719 - root_mean_squared_error: 547416.8125 - val_loss: 194839.5625 - val_root_mean_squared_error: 212918.9375
# Epoch 67/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231620.0938 - root_mean_squared_error: 547237.0625 - val_loss: 196915.6719 - val_root_mean_squared_error: 214550.4219
# Epoch 68/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231905.5469 - root_mean_squared_error: 546138.2500 - val_loss: 197463.5000 - val_root_mean_squared_error: 214276.6406
# Epoch 69/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232484.7500 - root_mean_squared_error: 547466.1250 - val_loss: 198723.5938 - val_root_mean_squared_error: 219901.0469
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233021.3750 - root_mean_squared_error: 547526.9375 - val_loss: 195864.3594 - val_root_mean_squared_error: 217658.6719
# Epoch 71/100
# 25/25 [==============================] - 0s 6ms/step - loss: 232523.4219 - root_mean_squared_error: 546607.6875 - val_loss: 196119.6562 - val_root_mean_squared_error: 215276.8594
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232016.2031 - root_mean_squared_error: 546606.4375 - val_loss: 196446.1406 - val_root_mean_squared_error: 216870.2031
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231728.0156 - root_mean_squared_error: 547247.0625 - val_loss: 202070.5781 - val_root_mean_squared_error: 214106.6875
# Epoch 74/100
# 25/25 [==============================] - 0s 5ms/step - loss: 237089.0938 - root_mean_squared_error: 549518.1875 - val_loss: 194201.2031 - val_root_mean_squared_error: 214423.9531
# Epoch 75/100
# 25/25 [==============================] - 0s 6ms/step - loss: 233152.6406 - root_mean_squared_error: 547897.0000 - val_loss: 201553.2031 - val_root_mean_squared_error: 221305.4375
# Epoch 76/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233300.1719 - root_mean_squared_error: 548473.1250 - val_loss: 195044.0938 - val_root_mean_squared_error: 214059.0156
# Epoch 77/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232536.7969 - root_mean_squared_error: 547286.1250 - val_loss: 198819.5938 - val_root_mean_squared_error: 219087.5000
# Epoch 78/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234348.8750 - root_mean_squared_error: 547788.5000 - val_loss: 195624.2969 - val_root_mean_squared_error: 216429.2031
# Epoch 79/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232880.3281 - root_mean_squared_error: 547271.1250 - val_loss: 195913.6875 - val_root_mean_squared_error: 214233.1250
# Epoch 80/100
# 25/25 [==============================] - 0s 6ms/step - loss: 231755.9688 - root_mean_squared_error: 546589.1875 - val_loss: 195164.7344 - val_root_mean_squared_error: 214926.5156
# Epoch 81/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235076.6562 - root_mean_squared_error: 547421.0625 - val_loss: 197160.5781 - val_root_mean_squared_error: 212383.5938
# Epoch 82/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233788.7188 - root_mean_squared_error: 546987.4375 - val_loss: 194445.4219 - val_root_mean_squared_error: 213728.4531
# Epoch 83/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231731.8906 - root_mean_squared_error: 545639.6875 - val_loss: 199012.8750 - val_root_mean_squared_error: 218713.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234164.0156 - root_mean_squared_error: 546979.5000 - val_loss: 195615.7188 - val_root_mean_squared_error: 212400.8750
# Epoch 85/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232789.3281 - root_mean_squared_error: 546780.0000 - val_loss: 196061.0625 - val_root_mean_squared_error: 213364.4844
# Epoch 86/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232544.9375 - root_mean_squared_error: 547391.4375 - val_loss: 196338.1250 - val_root_mean_squared_error: 213591.7344
# Epoch 87/100
# 25/25 [==============================] - 0s 5ms/step - loss: 233759.5938 - root_mean_squared_error: 546986.3125 - val_loss: 200037.0938 - val_root_mean_squared_error: 214680.2812
# Epoch 88/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231446.1562 - root_mean_squared_error: 546171.5000 - val_loss: 194131.2656 - val_root_mean_squared_error: 213475.7969
# Epoch 89/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235024.1094 - root_mean_squared_error: 546978.8125 - val_loss: 195153.8438 - val_root_mean_squared_error: 211768.1094
# Epoch 90/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234285.0312 - root_mean_squared_error: 548679.8750 - val_loss: 200538.6094 - val_root_mean_squared_error: 212802.8906
# Epoch 91/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235299.1406 - root_mean_squared_error: 547770.6875 - val_loss: 202033.1250 - val_root_mean_squared_error: 214981.4531
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234633.7031 - root_mean_squared_error: 547638.0625 - val_loss: 194065.3594 - val_root_mean_squared_error: 212607.9531
# Epoch 93/100
# 25/25 [==============================] - 0s 5ms/step - loss: 234661.8594 - root_mean_squared_error: 548550.3750 - val_loss: 198344.7812 - val_root_mean_squared_error: 212077.4531
# Epoch 94/100
# 25/25 [==============================] - 0s 5ms/step - loss: 235157.7031 - root_mean_squared_error: 548661.8125 - val_loss: 199519.5625 - val_root_mean_squared_error: 220239.4219
# Epoch 95/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232030.9219 - root_mean_squared_error: 546696.4375 - val_loss: 196073.0469 - val_root_mean_squared_error: 213094.7500
# Epoch 96/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231794.9219 - root_mean_squared_error: 547040.0000 - val_loss: 195111.9688 - val_root_mean_squared_error: 213409.0156
# Epoch 97/100
# 25/25 [==============================] - 0s 5ms/step - loss: 232935.2188 - root_mean_squared_error: 547121.6875 - val_loss: 197673.2969 - val_root_mean_squared_error: 218235.5938
# Epoch 98/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231161.2812 - root_mean_squared_error: 546021.6875 - val_loss: 194550.0469 - val_root_mean_squared_error: 214669.7812
# Epoch 99/100
# 25/25 [==============================] - 0s 5ms/step - loss: 231682.1562 - root_mean_squared_error: 546721.6250 - val_loss: 194931.6406 - val_root_mean_squared_error: 214330.2031
# Epoch 100/100
# 25/25 [==============================] - 0s 5ms/step - loss: 230954.3750 - root_mean_squared_error: 545771.4375 - val_loss: 195816.2812 - val_root_mean_squared_error: 211144.2812

# %%
plt.figure(figsize=(12,8))
plt.plot(process.history["loss"])
plt.plot(process.history["val_loss"])
plt.title("Model's Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])

plt.show();

# %%
plt.figure(figsize=(12,8))
plt.plot(process.history["root_mean_squared_error"])
plt.plot(process.history["val_root_mean_squared_error"])
plt.title("Model's Performance")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.legend(["Train", "Validation"])

plt.show();

# %%
model_house.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 218862.7188 - root_mean_squared_error: 262841.9062
# [218862.71875, 262841.90625]

# %%
y_true = tf.squeeze(y_test)
print(y_true.shape)
y_pred = tf.squeeze(model_house.predict(x_test))
print(y_pred.shape)
# Out:
# (460,)
# 15/15 [==============================] - 0s 2ms/step
# (460,)
# 2024-01-26 23:26:26.805952: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
ind = np.arange(len(y_true))
width = 0.4
plt.figure(figsize=(12,8))
plt.bar(ind, y_true, width)
plt.bar(ind, y_pred, width)
plt.title("Model's Performance")
plt.legend(["True Data", "Prediction"])

plt.show();
